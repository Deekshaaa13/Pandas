# %% [markdown]
# # Regular Expression

# %% [raw]
# Write a Pandas program to remove whitespaces, left sided whitespaces and right sided whitespaces of the string values of a given pandas series.

# %%
import pandas as pd
color1 = pd.Index([' Green', 'Black ', ' Red ', 'White', ' Pink '])
print(color1)
# Out:
# Index([' Green', 'Black ', ' Red ', 'White', ' Pink '], dtype='object')

# %%
print(color1.str.strip())
print(color1.str.lstrip())
print(color1.str.rstrip())
# Out:
# Index(['Green', 'Black', 'Red', 'White', 'Pink'], dtype='object')
# Index(['Green', 'Black ', 'Red ', 'White', 'Pink '], dtype='object')
# Index([' Green', 'Black', ' Red', 'White', ' Pink'], dtype='object')

# %% [raw]
# Add leading zeros to the integer column in a pandas series and makes the length of the field to 8 digit

# %%
nums = {'amount': [10, 250, 3000, 40000, 500000]}
print("Original dataframe:")
df = pd.DataFrame(nums)
print(df)
print("\nAdd leading zeros:")
# Out:
# Original dataframe:
#    amount
# 0      10
# 1     250
# 2    3000
# 3   40000
# 4  500000
#
# Add leading zeros:

# %%
df['amount']=df['amount'].apply(lambda x:'{0:0>8}'.format(x))
df
# Out:
#      amount
# 0  00000010
# 1  00000250
# 2  00003000
# 3  00040000
# 4  00500000

# %%
import pandas as pd
nums = {'amount': ['10', '250', '3000', '40000', '500000']}
print("Original dataframe:")
df = pd.DataFrame(nums)
print(df)
print("\nAdd leading zeros:")
df['amount'] = df['amount'].apply(lambda x:x.zfill(8))
print(df)
# Out:
# Original dataframe:
#    amount
# 0      10
# 1     250
# 2    3000
# 3   40000
# 4  500000
#
# Add leading zeros:
#      amount
# 0  00000010
# 1  00000250
# 2  00003000
# 3  00040000
# 4  00500000

# %% [raw]
# Write a Pandas program to capitalize all the string values of specified columns of a given DataFrame.

# %%
df = pd.DataFrame({
    'name': ['alberto','gino','ryan', 'Eesha', 'syed'],
    'date_of_birth ': ['17/05/2002','16/02/1999','25/09/1998','11/05/2002','15/09/1997'],
    'age': [18.5, 21.2, 22.5, 22, 23]
})
print("Original DataFrame:")
print(df)
# Out:
# Original DataFrame:
#       name date_of_birth    age
# 0  alberto     17/05/2002  18.5
# 1     gino     16/02/1999  21.2
# 2     ryan     25/09/1998  22.5
# 3    Eesha     11/05/2002  22.0
# 4     syed     15/09/1997  23.0

# %%
df['name']=df['name'].str.capitalize()

# %%
df
# Out:
#       name date_of_birth    age
# 0  Alberto     17/05/2002  18.5
# 1     Gino     16/02/1999  21.2
# 2     Ryan     25/09/1998  22.5
# 3    Eesha     11/05/2002  22.0
# 4     Syed     15/09/1997  23.0

# %% [raw]
# Write a Pandas program to count of occurrence of a specified substring in a DataFrame column.

# %%
df = pd.DataFrame({
    'name_code': ['c001','c002','c022', 'c2002', 'c2222'],
    'date_of_birth ': ['12/05/2002','16/02/1999','25/09/1998','12/02/2022','15/09/1997'],
    'age': [18.5, 21.2, 22.5, 22, 23]
})
print("Original DataFrame:")
print(df)
# Out:
# Original DataFrame:
#   name_code date_of_birth    age
# 0      c001     12/05/2002  18.5
# 1      c002     16/02/1999  21.2
# 2      c022     25/09/1998  22.5
# 3     c2002     12/02/2022  22.0
# 4     c2222     15/09/1997  23.0

# %%
df['count']=list(map(lambda x:x.count('2'),df['name_code']))
df
# Out:
#   name_code date_of_birth    age  count
# 0      c001     12/05/2002  18.5      0
# 1      c002     16/02/1999  21.2      1
# 2      c022     25/09/1998  22.5      2
# 3     c2002     12/02/2022  22.0      2
# 4     c2222     15/09/1997  23.0      4

# %% [raw]
# Write a Pandas program to find the index of a given substring of a DataFrame column.

# %%
df = pd.DataFrame({
    'name_code': ['c001','c002','c022', 'c2002', 'c2222'],
    'date_of_birth ': ['12/05/2002','16/02/1999','25/09/1998','12/02/2022','15/09/1997'],
    'age': [18.5, 21.2, 22.5, 22, 23]
})
print("Original DataFrame:")
print(df)
df['Index']=list(map(lambda x: x.find('22'),df['name_code']))
df
# Out:
# Original DataFrame:
#   name_code date_of_birth    age
# 0      c001     12/05/2002  18.5
# 1      c002     16/02/1999  21.2
# 2      c022     25/09/1998  22.5
# 3     c2002     12/02/2022  22.0
# 4     c2222     15/09/1997  23.0
#   name_code date_of_birth    age  Index
# 0      c001     12/05/2002  18.5     -1
# 1      c002     16/02/1999  21.2     -1
# 2      c022     25/09/1998  22.5      2
# 3     c2002     12/02/2022  22.0     -1
# 4     c2222     15/09/1997  23.0      1

# %% [raw]
# Find the index of a substring of DataFrame with beginning and end position

# %%
df = pd.DataFrame({
    'name_code': ['c001','c002','c022', 'c2002', 'c2222'],
    'date_of_birth ': ['12/05/2002','16/02/1999','25/09/1998','12/02/2022','15/09/1997'],
    'age': [18.5, 21.2, 22.5, 22, 23]
})
print("Original DataFrame:")
print(df)
df['Index']=list(map(lambda x:x.find('c',0,5),df['name_code']))
df
# Out:
# Original DataFrame:
#   name_code date_of_birth    age
# 0      c001     12/05/2002  18.5
# 1      c002     16/02/1999  21.2
# 2      c022     25/09/1998  22.5
# 3     c2002     12/02/2022  22.0
# 4     c2222     15/09/1997  23.0
#   name_code date_of_birth    age  Index
# 0      c001     12/05/2002  18.5      0
# 1      c002     16/02/1999  21.2      0
# 2      c022     25/09/1998  22.5      0
# 3     c2002     12/02/2022  22.0      0
# 4     c2222     15/09/1997  23.0      0

# %%
df = pd.DataFrame({
    'name_code': ['c0001','1000c','b00c2', 'b2c02', 'c2222'],
    'date_of_birth ': ['12/05/2002','16/02/1999','25/09/1998','12/02/2022','15/09/1997'],
    'age': [18.5, 21.2, 22.5, 22, 23]
})
print("Original DataFrame:")
print(df)
print("\nIndex of a substring in a specified column of a dataframe:")
df['Index']=list(map(lambda x:x.find('c',0,5),df['name_code']))
print(df)
# Out:
# Original DataFrame:
#   name_code date_of_birth    age
# 0     c0001     12/05/2002  18.5
# 1     1000c     16/02/1999  21.2
# 2     b00c2     25/09/1998  22.5
# 3     b2c02     12/02/2022  22.0
# 4     c2222     15/09/1997  23.0
#
# Index of a substring in a specified column of a dataframe:
#   name_code date_of_birth    age  Index
# 0     c0001     12/05/2002  18.5      0
# 1     1000c     16/02/1999  21.2      4
# 2     b00c2     25/09/1998  22.5      3
# 3     b2c02     12/02/2022  22.0      2
# 4     c2222     15/09/1997  23.0      0

# %% [raw]
# Write a Pandas program to check whether alpha numeric values present in a given column of a DataFrame.

# %%
df = pd.DataFrame({
    'name_code': ['Company','Company a001','Company 123', '1234', 'Company 12'],
    'date_of_birth ': ['12/05/2002','16/02/1999','25/09/1998','12/02/2022','15/09/1997'],
    'age': [18.5, 21.2, 22.5, 22, 23]
})
print("Original DataFrame:")
print(df)
print("\nWhether all characters in the string are alphanumeric?")
df['name_code_is_alphanumeric'] = list(map(lambda x: x.isalnum(), df['name_code']))
print(df)
# Out:
# Original DataFrame:
#       name_code date_of_birth    age
# 0       Company     12/05/2002  18.5
# 1  Company a001     16/02/1999  21.2
# 2   Company 123     25/09/1998  22.5
# 3          1234     12/02/2022  22.0
# 4    Company 12     15/09/1997  23.0
#
# Whether all characters in the string are alphanumeric?
#       name_code date_of_birth    age  name_code_is_alphanumeric
# 0       Company     12/05/2002  18.5                       True
# 1  Company a001     16/02/1999  21.2                      False
# 2   Company 123     25/09/1998  22.5                      False
# 3          1234     12/02/2022  22.0                       True
# 4    Company 12     15/09/1997  23.0                      False

# %% [raw]
# Write a Pandas program to check whether alphabetic values present in a given column of a DataFrame.

# %%
df['name_code_is_alpha'] = list(map(lambda x: x.isalpha(), df['name_code'])))
# Out:
#       name_code date_of_birth    age  name_code_is_alphanumeric  \
# 0       Company     12/05/2002  18.5                       True
# 1  Company a001     16/02/1999  21.2                      False
# 2   Company 123     25/09/1998  22.5                      False
# 3          1234     12/02/2022  22.0                       True
# 4    Company 12     15/09/1997  23.0                      False
#
#    name_code_is_alpha
# 0                True
# 1               False
# 2               False
# 3               False
# 4               False

# %% [raw]
# Write a Pandas program to check whether only numeric values present in a given column of a DataFrame.

# %%
df['name_code_is_digit'] = list(map(lambda x: x.isdigit(), df['name_code']))

# %%
df
# Out:
#       name_code date_of_birth    age  name_code_is_alphanumeric  \
# 0       Company     12/05/2002  18.5                       True
# 1  Company a001     16/02/1999  21.2                      False
# 2   Company 123     25/09/1998  22.5                      False
# 3          1234     12/02/2022  22.0                       True
# 4    Company 12     15/09/1997  23.0                      False
#
#    company_code_is_alpha  name_code_is_alpha  name_code_is_digit
# 0                   True                True               False
# 1                  False               False               False
# 2                  False               False               False
# 3                  False               False                True
# 4                  False               False               False

# %%
df.drop('company_code_is_alpha',axis=1,inplace=True)

# %%
df
# Out:
#       name_code date_of_birth    age  name_code_is_alphanumeric  \
# 0       Company     12/05/2002  18.5                       True
# 1  Company a001     16/02/1999  21.2                      False
# 2   Company 123     25/09/1998  22.5                      False
# 3          1234     12/02/2022  22.0                       True
# 4    Company 12     15/09/1997  23.0                      False
#
#    name_code_is_alpha  name_code_is_digit
# 0                True               False
# 1               False               False
# 2               False               False
# 3               False                True
# 4               False               False

# %% [raw]
# Write a Pandas program to check whether only lower case or upper case is present in a given column of a DataFrame.

# %%
df = pd.DataFrame({
    'company_code': ['Afgh','EFGF', 'hhhh', 'abcd', 'EAWQaaa'],
    'date_of_sale ': ['12/05/2002','16/02/1999','25/09/1998','12/02/2022','15/09/1997'],
    'sale_amount': [12348.5, 233331.2, 22.5, 2566552.0, 23.0]})

print("Original DataFrame:")
print(df)
# Out:
# Original DataFrame:
#   company_code date_of_sale   sale_amount
# 0         Afgh    12/05/2002      12348.5
# 1         EFGF    16/02/1999     233331.2
# 2         hhhh    25/09/1998         22.5
# 3         abcd    12/02/2022    2566552.0
# 4      EAWQaaa    15/09/1997         23.0

# %%
df['company_code_ul_cases'] = list(map(lambda x: x.islower(), df['company_code']))
print(df)
print("\nIs Upper (company_code)?")
df['company_code_ul_cases'] = list(map(lambda x: x.isupper(), df['company_code']))
print(df)
# Out:
#   company_code date_of_sale   sale_amount  company_code_ul_cases
# 0         ABCD    12/05/2002      12348.5                  False
# 1         EFGF    16/02/1999     233331.2                  False
# 2         hhhh    25/09/1998         22.5                   True
# 3         abcd    12/02/2022    2566552.0                   True
# 4      EAWQaaa    15/09/1997         23.0                  False
#
# Is Upper (company_code)?
#   company_code date_of_sale   sale_amount  company_code_ul_cases
# 0         ABCD    12/05/2002      12348.5                   True
# 1         EFGF    16/02/1999     233331.2                   True
# 2         hhhh    25/09/1998         22.5                  False
# 3         abcd    12/02/2022    2566552.0                  False
# 4      EAWQaaa    15/09/1997         23.0                  False

# %% [raw]
# Write a Pandas program to check whether only proper case or title case is present in a given column of a DataFrame.

# %%
df['company_code_is_title'] = list(map(lambda x: x.istitle(), df['company_code']))

# %%
df
# Out:
#   company_code date_of_sale   sale_amount  company_code_is_title
# 0         Afgh    12/05/2002      12348.5                   True
# 1         EFGF    16/02/1999     233331.2                  False
# 2         hhhh    25/09/1998         22.5                  False
# 3         abcd    12/02/2022    2566552.0                  False
# 4      EAWQaaa    15/09/1997         23.0                  False

# %% [raw]
# Write a Pandas program to check whether only space is present in a given column of a DataFrame.

# %%
df['company_code_is_title'] = list(map(lambda x: x.isspace(), df['company_code']))
df
# Out:
#   company_code date_of_sale   sale_amount  company_code_is_title
# 0         Afgh    12/05/2002      12348.5                  False
# 1         EFGF    16/02/1999     233331.2                  False
# 2         hhhh    25/09/1998         22.5                  False
# 3         abcd    12/02/2022    2566552.0                  False
# 4      EAWQaaa    15/09/1997         23.0                  False

# %% [raw]
# Write a Pandas program to get the length of the string present of a given column in a DataFrame.

# %%
df['len']=list(map(lambda x:len(x),df['company_code']))
df
# Out:
#   company_code date_of_sale   sale_amount  company_code_is_title  len
# 0         Afgh    12/05/2002      12348.5                  False    4
# 1         EFGF    16/02/1999     233331.2                  False    4
# 2         hhhh    25/09/1998         22.5                  False    4
# 3         abcd    12/02/2022    2566552.0                  False    4
# 4      EAWQaaa    15/09/1997         23.0                  False    7

# %% [raw]
# Write a Pandas program to get the length of the integer of a given column in a DataFrame.

# %%
df = pd.DataFrame({
    'company_code': ['Abcd','EFGF', 'skfsalf', 'sdfslew', 'safsdf'],
    'date_of_sale': ['12/05/2002','16/02/1999','25/09/1998','12/02/2022','15/09/1997'],
    'sale_amount': [12348.5, 233331.2, 22.5, 2566552.0, 23.0]
})
print("Original DataFrame:")
print(df)
print("\nLength of sale_amount:")
df['len_int']=df['sale_amount'].map(str).apply(len)
# Out:
# Original DataFrame:
#   company_code date_of_sale  sale_amount
# 0         Abcd   12/05/2002      12348.5
# 1         EFGF   16/02/1999     233331.2
# 2      skfsalf   25/09/1998         22.5
# 3      sdfslew   12/02/2022    2566552.0
# 4       safsdf   15/09/1997         23.0
#
# Length of sale_amount:

# %%
df
# Out:
#   company_code date_of_sale  sale_amount  len_int
# 0         Abcd   12/05/2002      12348.5        7
# 1         EFGF   16/02/1999     233331.2        8
# 2      skfsalf   25/09/1998         22.5        4
# 3      sdfslew   12/02/2022    2566552.0        9
# 4       safsdf   15/09/1997         23.0        4

# %% [raw]
# Write a Pandas program to check if a specified column starts with a specified string in a DataFrame.

# %%
df['company_code_starts_with'] = list(
    map(lambda x: x.startswith('s'), df['company_code']))
df
# Out:
#   company_code date_of_sale  sale_amount  len_int  company_code_starts_with
# 0         Abcd   12/05/2002      12348.5        7                     False
# 1         EFGF   16/02/1999     233331.2        8                     False
# 2      skfsalf   25/09/1998         22.5        4                      True
# 3      sdfslew   12/02/2022    2566552.0        9                      True
# 4       safsdf   15/09/1997         23.0        4                      True

# %% [raw]
# Write a Pandas program to swap the cases of a specified character column in a given DataFrame.

# %%
df['swap_case'] = list(
    map(lambda x: x.swapcase(), df['company_code']))
df
# Out:
#   company_code date_of_sale  sale_amount  len_int  company_code_starts_with  \
# 0         Abcd   12/05/2002      12348.5        7                     False
# 1         EFGF   16/02/1999     233331.2        8                     False
# 2      skfsalf   25/09/1998         22.5        4                      True
# 3      sdfslew   12/02/2022    2566552.0        9                      True
# 4       safsdf   15/09/1997         23.0        4                      True
#
#   swap_case
# 0      aBCD
# 1      efgf
# 2   SKFSALF
# 3   SDFSLEW
# 4    SAFSDF

# %% [raw]
# Write a Pandas program to convert a specified character column in title case in a given DataFrame.

# %%
df['title'] = list(
    map(lambda x: x.swapcase(), df['company_code']))
df
# Out:
#   company_code date_of_sale  sale_amount  len_int  company_code_starts_with  \
# 0         Abcd   12/05/2002      12348.5        7                     False
# 1         EFGF   16/02/1999     233331.2        8                     False
# 2      skfsalf   25/09/1998         22.5        4                      True
# 3      sdfslew   12/02/2022    2566552.0        9                      True
# 4       safsdf   15/09/1997         23.0        4                      True
#
#   swap_case    title
# 0      aBCD     aBCD
# 1      efgf     efgf
# 2   SKFSALF  SKFSALF
# 3   SDFSLEW  SDFSLEW
# 4    SAFSDF   SAFSDF

# %% [raw]
# Write a Pandas program to replace arbitrary values with other values in a given DataFrame

# %%
df = pd.DataFrame({
    'company_code': ['A','B', 'C', 'D', 'A'],
    'date_of_sale': ['12/05/2002','16/02/1999','25/09/1998','12/02/2022','15/09/1997'],
    'sale_amount': [12348.5, 233331.2, 22.5, 2566552.0, 23.0]
})

print("Original DataFrame:")
print(df)
df=df.replace('A','C')
df
# Out:
# Original DataFrame:
#   company_code date_of_sale  sale_amount
# 0            A   12/05/2002      12348.5
# 1            B   16/02/1999     233331.2
# 2            C   25/09/1998         22.5
# 3            D   12/02/2022    2566552.0
# 4            A   15/09/1997         23.0
#   company_code date_of_sale  sale_amount
# 0            C   12/05/2002      12348.5
# 1            B   16/02/1999     233331.2
# 2            C   25/09/1998         22.5
# 3            D   12/02/2022    2566552.0
# 4            C   15/09/1997         23.0

# %% [raw]
# Write a Pandas program to replace more than one value with other values in a given DataFrame.

# %%
df=df.replace(['B','C'],['X','Y'])
df
# Out:
#   company_code date_of_sale  sale_amount
# 0            Y   12/05/2002      12348.5
# 1            X   16/02/1999     233331.2
# 2            Y   25/09/1998         22.5
# 3            D   12/02/2022    2566552.0
# 4            Y   15/09/1997         23.0

# %% [markdown]
# # Join

# %% [raw]
# Write a Pandas program to join the two given dataframes along rows and assign all data.

# %%
student_data1 = pd.DataFrame({
        'student_id': ['S1', 'S2', 'S3', 'S4', 'S5'],
         'name': ['Danniella Fenton', 'Ryder Storey', 'Bryce Jensen', 'Ed Bernal', 'Kwame Morin'], 
        'marks': [200, 210, 190, 222, 199]})

student_data2 = pd.DataFrame({
        'student_id': ['S4', 'S5', 'S6', 'S7', 'S8'],
        'name': ['Scarlette Fisher', 'Carla Williamson', 'Dante Morse', 'Kaiser William', 'Madeeha Preston'], 
        'marks': [201, 200, 198, 219, 201]})

print("Original DataFrames:")
print(student_data1)
print("-------------------------------------")
print(student_data2)
# Out:
# Original DataFrames:
#   student_id              name  marks
# 0         S1  Danniella Fenton    200
# 1         S2      Ryder Storey    210
# 2         S3      Bryce Jensen    190
# 3         S4         Ed Bernal    222
# 4         S5       Kwame Morin    199
# -------------------------------------
#   student_id              name  marks
# 0         S4  Scarlette Fisher    201
# 1         S5  Carla Williamson    200
# 2         S6       Dante Morse    198
# 3         S7    Kaiser William    219
# 4         S8   Madeeha Preston    201

# %%
df_new=pd.concat([student_data1,student_data2])
df_new.reset_index(drop=True)
# Out:
#   student_id              name  marks
# 0         S1  Danniella Fenton    200
# 1         S2      Ryder Storey    210
# 2         S3      Bryce Jensen    190
# 3         S4         Ed Bernal    222
# 4         S5       Kwame Morin    199
# 5         S4  Scarlette Fisher    201
# 6         S5  Carla Williamson    200
# 7         S6       Dante Morse    198
# 8         S7    Kaiser William    219
# 9         S8   Madeeha Preston    201

# %% [raw]
# Write a Pandas program to join the two given dataframes along columns and assign all data.

# %%
df_new=pd.concat([student_data1,student_data2],axis=1)
df_new
# Out:
#   student_id              name  marks student_id              name  marks
# 0         S1  Danniella Fenton    200         S4  Scarlette Fisher    201
# 1         S2      Ryder Storey    210         S5  Carla Williamson    200
# 2         S3      Bryce Jensen    190         S6       Dante Morse    198
# 3         S4         Ed Bernal    222         S7    Kaiser William    219
# 4         S5       Kwame Morin    199         S8   Madeeha Preston    201

# %% [raw]
# Write a Pandas program to append rows to an existing DataFrame and display the combined data.

# %%
s6=pd.Series(['S6', 'Scarlette Fisher', 205],index=['student_id', 'name', 'marks'])
print(student_data1)
df_new=student_data1.append(s6,ignore_index=True)
df_new
# Out:
#   student_id              name  marks
# 0         S1  Danniella Fenton    200
# 1         S2      Ryder Storey    210
# 2         S3      Bryce Jensen    190
# 3         S4         Ed Bernal    222
# 4         S5       Kwame Morin    199
#   student_id              name  marks
# 0         S1  Danniella Fenton    200
# 1         S2      Ryder Storey    210
# 2         S3      Bryce Jensen    190
# 3         S4         Ed Bernal    222
# 4         S5       Kwame Morin    199
# 5         S6  Scarlette Fisher    205

# %% [raw]
# Write a Pandas program to append a list of dictioneries or series to a existing DataFrame and display the combined data.

# %%
student_data1  = pd.DataFrame({
        'student_id': ['S1', 'S2', 'S3', 'S4', 'S5'],
         'name': ['Danniella Fenton', 'Ryder Storey', 'Bryce Jensen', 'Ed Bernal', 'Kwame Morin'], 
        'marks': [200, 210, 190, 222, 199]})

# %%
dicts = [{'student_id': 'S6', 'name': 'Scarlette Fisher', 'marks': 203},
         {'student_id': 'S7', 'name': 'Bryce Jensen', 'marks': 207}]

# %%
df_new=student_data1.append(dicts,sort=False)
df_new
# Out:
#   student_id              name  marks
# 0         S1  Danniella Fenton    200
# 1         S2      Ryder Storey    210
# 2         S3      Bryce Jensen    190
# 3         S4         Ed Bernal    222
# 4         S5       Kwame Morin    199
# 0         S6  Scarlette Fisher    203
# 1         S7      Bryce Jensen    207

# %% [raw]
# Write a Pandas program to join the two given dataframes along rows and merge with another dataframe along the common column id.

# %%
student_data1 = pd.DataFrame({
        'student_id': ['S1', 'S2', 'S3', 'S4', 'S5'],
         'name': ['Danniella Fenton', 'Ryder Storey', 'Bryce Jensen', 'Ed Bernal', 'Kwame Morin'], 
        'marks': [200, 210, 190, 222, 199]})

student_data2 = pd.DataFrame({
        'student_id': ['S4', 'S5', 'S6', 'S7', 'S8'],
        'name': ['Scarlette Fisher', 'Carla Williamson', 'Dante Morse', 'Kaiser William', 'Madeeha Preston'], 
        'marks': [201, 200, 198, 219, 201]})

exam_data = pd.DataFrame({
        'student_id': ['S1', 'S2', 'S3', 'S4', 'S5', 'S7', 'S8', 'S9', 'S10', 'S11', 'S12', 'S13'],
        'exam_id': [23, 45, 12, 67, 21, 55, 33, 14, 56, 83, 88, 12]})

print("Original DataFrames:")
print(student_data1)
print(student_data2)
print(exam_data)
# Out:
# Original DataFrames:
#   student_id              name  marks
# 0         S1  Danniella Fenton    200
# 1         S2      Ryder Storey    210
# 2         S3      Bryce Jensen    190
# 3         S4         Ed Bernal    222
# 4         S5       Kwame Morin    199
#   student_id              name  marks
# 0         S4  Scarlette Fisher    201
# 1         S5  Carla Williamson    200
# 2         S6       Dante Morse    198
# 3         S7    Kaiser William    219
# 4         S8   Madeeha Preston    201
#    student_id  exam_id
# 0          S1       23
# 1          S2       45
# 2          S3       12
# 3          S4       67
# 4          S5       21
# 5          S7       55
# 6          S8       33
# 7          S9       14
# 8         S10       56
# 9         S11       83
# 10        S12       88
# 11        S13       12

# %%
result_data=pd.concat([student_data1,student_data2])
final_df=pd.merge(exam_data,result_data,on='student_id')
final_df
# Out:
#   student_id  exam_id              name  marks
# 0         S1       23  Danniella Fenton    200
# 1         S2       45      Ryder Storey    210
# 2         S3       12      Bryce Jensen    190
# 3         S4       67         Ed Bernal    222
# 4         S4       67  Scarlette Fisher    201
# 5         S5       21       Kwame Morin    199
# 6         S5       21  Carla Williamson    200
# 7         S7       55    Kaiser William    219
# 8         S8       33   Madeeha Preston    201

# %% [raw]
# Merge only the data that has the same column on both dataframes (inner join)

# %%
final_df=pd.merge(student_data1,student_data2,on='student_id',how='inner')
final_df
# Out:
#   student_id       name_x  marks_x            name_y  marks_y
# 0         S4    Ed Bernal      222  Scarlette Fisher      201
# 1         S5  Kwame Morin      199  Carla Williamson      200

# %% [raw]
# Merge all values in two datasets, with matching records from both sides where available

# %%
final_df=pd.merge(student_data1,student_data2,on='student_id',how='outer')

# %%
final_df
# Out:
#   student_id            name_x  marks_x            name_y  marks_y
# 0         S1  Danniella Fenton    200.0               NaN      NaN
# 1         S2      Ryder Storey    210.0               NaN      NaN
# 2         S3      Bryce Jensen    190.0               NaN      NaN
# 3         S4         Ed Bernal    222.0  Scarlette Fisher    201.0
# 4         S5       Kwame Morin    199.0  Carla Williamson    200.0
# 5         S6               NaN      NaN       Dante Morse    198.0
# 6         S7               NaN      NaN    Kaiser William    219.0
# 7         S8               NaN      NaN   Madeeha Preston    201.0

# %%
data1 = pd.DataFrame({'key1': ['K0', 'K0', 'K1', 'K2'],
                     'key2': ['K0', 'K1', 'K0', 'K1'],
                     'P': ['P0', 'P1', 'P2', 'P3'],
                     'Q': ['Q0', 'Q1', 'Q2', 'Q3']}) 
data2 = pd.DataFrame({'key1': ['K0', 'K1', 'K1', 'K2'],
                      'key2': ['K0', 'K0', 'K0', 'K0'],
                      'R': ['R0', 'R1', 'R2', 'R3'],
                      'S': ['S0', 'S1', 'S2', 'S3']})
print("Original DataFrames:")
print(data1)
print("--------------------")
print(data2)
# Out:
# Original DataFrames:
#   key1 key2   P   Q
# 0   K0   K0  P0  Q0
# 1   K0   K1  P1  Q1
# 2   K1   K0  P2  Q2
# 3   K2   K1  P3  Q3
# --------------------
#   key1 key2   R   S
# 0   K0   K0  R0  S0
# 1   K1   K0  R1  S1
# 2   K1   K0  R2  S2
# 3   K2   K0  R3  S3

# %%
final_df=pd.merge(data1,data2,on=['key1','key2'],how='left')

# %%
final_df
# Out:
#   key1 key2   P   Q    R    S
# 0   K0   K0  P0  Q0   R0   S0
# 1   K0   K1  P1  Q1  NaN  NaN
# 2   K1   K0  P2  Q2   R1   S1
# 3   K1   K0  P2  Q2   R2   S2
# 4   K2   K1  P3  Q3  NaN  NaN

# %%
print("Original DataFrames:")
print(data1)
print("--------------------")
print(data2)
final_df=pd.merge(data1,data2,on=['key1','key2'],how='right')
final_df
# Out:
# Original DataFrames:
#   key1 key2   P   Q
# 0   K0   K0  P0  Q0
# 1   K0   K1  P1  Q1
# 2   K1   K0  P2  Q2
# 3   K2   K1  P3  Q3
# --------------------
#   key1 key2   R   S
# 0   K0   K0  R0  S0
# 1   K1   K0  R1  S1
# 2   K1   K0  R2  S2
# 3   K2   K0  R3  S3
#   key1 key2    P    Q   R   S
# 0   K0   K0   P0   Q0  R0  S0
# 1   K1   K0   P2   Q2  R1  S1
# 2   K1   K0   P2   Q2  R2  S2
# 3   K2   K0  NaN  NaN  R3  S3

# %% [raw]
# One to many join

# %%
result_df=pd.merge(data1,data2,on='key1')
result_df
# Out:
#   key1 key2_x   P   Q key2_y   R   S
# 0   K0     K0  P0  Q0     K0  R0  S0
# 1   K0     K1  P1  Q1     K0  R0  S0
# 2   K1     K0  P2  Q2     K0  R1  S1
# 3   K1     K0  P2  Q2     K0  R2  S2
# 4   K2     K1  P3  Q3     K0  R3  S3

# %% [raw]
# data1.join(data2) is same as left join data1 with data 2

# %% [raw]
# Write a Pandas program to merge two given dataframes with different columns.

# %%
result = pd.concat([data1,data2], axis=0, ignore_index=True)
print(result)
# Out:
#   key1 key2    P    Q    R    S
# 0   K0   K0   P0   Q0  NaN  NaN
# 1   K0   K1   P1   Q1  NaN  NaN
# 2   K1   K0   P2   Q2  NaN  NaN
# 3   K2   K1   P3   Q3  NaN  NaN
# 4   K0   K0  NaN  NaN   R0   S0
# 5   K1   K0  NaN  NaN   R1   S1
# 6   K1   K0  NaN  NaN   R2   S2
# 7   K2   K0  NaN  NaN   R3   S3

# %% [markdown]
# # Filter

# %%
df=pd.read_csv('ratings.csv')

# %%
df
# Out:
#         userId  movieId  rating   timestamp
# 0            1        1     4.0   964982703
# 1            1        3     4.0   964981247
# 2            1        6     4.0   964982224
# 3            1       47     5.0   964983815
# 4            1       50     5.0   964982931
# ...        ...      ...     ...         ...
# 100831     610   166534     4.0  1493848402
# 100832     610   168248     5.0  1493850091
# 100833     610   168250     5.0  1494273047
# 100834     610   168252     5.0  1493846352
# 100835     610   170875     3.0  1493846415
#
# [100836 rows x 4 columns]

# %%
df.shape
# Out:
# (100836, 4)

# %%
df.columns
# Out:
# Index(['userId', 'movieId', 'rating', 'timestamp'], dtype='object')

# %% [raw]
# Select random number of rows, fraction of random rows

# %%
df.sample(5)
# Out:
#        userId  movieId  rating   timestamp
# 26629     182     3448     4.5  1054782674
# 61904     410     1260     5.0   990909349
# 17816     111   140715     4.5  1518640686
# 312         4      190     2.0   945079259
# 59965     387     6290     1.0  1183962926

# %%
df.sample(frac=0.2)
# Out:
#        userId  movieId  rating   timestamp
# 18090     113     3476     4.0   980307528
# 55429     368      260     4.0   975828806
# 66186     425    73323     4.0  1281209190
# 19103     122   115122     5.0  1461562651
# 94860     599    93510     2.5  1498529982
# ...       ...      ...     ...         ...
# 32567     221    27815     3.5  1121365450
# 89110     577     1213     4.0   945966718
# 26213     182      784     2.0  1055156182
# 60940     394       50     5.0   838994626
# 61231     401    30793     3.0  1514347062
#
# [20167 rows x 4 columns]

# %%
df.head()
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931

# %%
df.isnull()
# Out:
#         userId  movieId  rating  timestamp
# 0        False    False   False      False
# 1        False    False   False      False
# 2        False    False   False      False
# 3        False    False   False      False
# 4        False    False   False      False
# ...        ...      ...     ...        ...
# 100831   False    False   False      False
# 100832   False    False   False      False
# 100833   False    False   False      False
# 100834   False    False   False      False
# 100835   False    False   False      False
#
# [100836 rows x 4 columns]

# %%
df.dropna()
# Out:
#         userId  movieId  rating   timestamp
# 0            1        1     4.0   964982703
# 1            1        3     4.0   964981247
# 2            1        6     4.0   964982224
# 3            1       47     5.0   964983815
# 4            1       50     5.0   964982931
# ...        ...      ...     ...         ...
# 100831     610   166534     4.0  1493848402
# 100832     610   168248     5.0  1493850091
# 100833     610   168250     5.0  1494273047
# 100834     610   168252     5.0  1493846352
# 100835     610   170875     3.0  1493846415
#
# [100836 rows x 4 columns]

# %%
df.drop_duplicates('userId')
# Out:
#        userId  movieId  rating   timestamp
# 0           1        1     4.0   964982703
# 232         2      318     3.0  1445714835
# 261         3       31     0.5  1306463578
# 300         4       21     3.0   986935199
# 516         5        1     4.0   847434962
# ...       ...      ...     ...         ...
# 97364     606        1     2.5  1349082950
# 98479     607        1     4.0   964744033
# 98666     608        1     2.5  1117408267
# 99497     609        1     3.0   847221025
# 99534     610        1     5.0  1479542900
#
# [610 rows x 4 columns]

# %% [raw]
# Filter by values using Boolean Logic in a given dataframe

# %%
df[df['userId']==610]
# Out:
#         userId  movieId  rating   timestamp
# 99534      610        1     5.0  1479542900
# 99535      610        6     5.0  1493850345
# 99536      610       16     4.5  1479542171
# 99537      610       32     4.5  1479543331
# 99538      610       47     5.0  1479545853
# ...        ...      ...     ...         ...
# 100831     610   166534     4.0  1493848402
# 100832     610   168248     5.0  1493850091
# 100833     610   168250     5.0  1494273047
# 100834     610   168252     5.0  1493846352
# 100835     610   170875     3.0  1493846415
#
# [1302 rows x 4 columns]

# %% [raw]
# Filter by values using Boolean OR Logic in a given dataframe

# %%
df[(df['userId']==610) | (df['userId']==608)]
# Out:
#         userId  movieId  rating   timestamp
# 98666      608        1     2.5  1117408267
# 98667      608        2     2.0  1117490786
# 98668      608        3     2.0  1117504413
# 98669      608       10     4.0  1117408486
# 98670      608       16     4.5  1189471181
# ...        ...      ...     ...         ...
# 100831     610   166534     4.0  1493848402
# 100832     610   168248     5.0  1493850091
# 100833     610   168250     5.0  1494273047
# 100834     610   168252     5.0  1493846352
# 100835     610   170875     3.0  1493846415
#
# [2133 rows x 4 columns]

# %% [raw]
# Filter by values using Boolean AND Logic in a given dataframe

# %%
df[(df['userId']==610) & (df['rating']==5.0)]
# Out:
#         userId  movieId  rating   timestamp
# 99534      610        1     5.0  1479542900
# 99535      610        6     5.0  1493850345
# 99538      610       47     5.0  1479545853
# 99543      610      111     5.0  1479542162
# 99547      610      194     5.0  1479544506
# ...        ...      ...     ...         ...
# 100814     610   158238     5.0  1479545219
# 100829     610   164179     5.0  1493845631
# 100832     610   168248     5.0  1493850091
# 100833     610   168250     5.0  1494273047
# 100834     610   168252     5.0  1493846352
#
# [180 rows x 4 columns]

# %% [raw]
# Filtering records by multiple condition, Comparison, Arithmetic Operators in a given dataframe

# %%
df[(df['userId']>=610)&(df['rating']!=5)]
# Out:
#         userId  movieId  rating   timestamp
# 99536      610       16     4.5  1479542171
# 99537      610       32     4.5  1479543331
# 99539      610       50     4.0  1493844757
# 99540      610       70     4.0  1495959282
# 99541      610       95     3.5  1479542004
# ...        ...      ...     ...         ...
# 100827     610   163937     3.5  1493848789
# 100828     610   163981     3.5  1493850155
# 100830     610   166528     4.0  1493879365
# 100831     610   166534     4.0  1493848402
# 100835     610   170875     3.0  1493846415
#
# [1122 rows x 4 columns]

# %% [raw]
# Filtering records by label or index in a given dataframe

# %%
df=df.reindex()

# %%
df
# Out:
#         userId  movieId  rating   timestamp
# 0            1        1     4.0   964982703
# 1            1        3     4.0   964981247
# 2            1        6     4.0   964982224
# 3            1       47     5.0   964983815
# 4            1       50     5.0   964982931
# ...        ...      ...     ...         ...
# 100831     610   166534     4.0  1493848402
# 100832     610   168248     5.0  1493850091
# 100833     610   168250     5.0  1494273047
# 100834     610   168252     5.0  1493846352
# 100835     610   170875     3.0  1493846415
#
# [100836 rows x 4 columns]

# %% [raw]
# Match if a given column has a particular sub string in a given dataframe

# %%
df=df.dropna()

# %%
df
# Out:
#         userId  movieId  rating   timestamp
# 0            1        1     4.0   964982703
# 1            1        3     4.0   964981247
# 2            1        6     4.0   964982224
# 3            1       47     5.0   964983815
# 4            1       50     5.0   964982931
# ...        ...      ...     ...         ...
# 100831     610   166534     4.0  1493848402
# 100832     610   168248     5.0  1493850091
# 100833     610   168250     5.0  1494273047
# 100834     610   168252     5.0  1493846352
# 100835     610   170875     3.0  1493846415
#
# [100836 rows x 4 columns]

# %% [raw]
# Match if a given column has a particular sub string in a given dataframe

# %%
df[df['userId'].map(str).str.contains('6')]
# Out:
#         userId  movieId  rating   timestamp
# 560          6        2     4.0   845553522
# 561          6        3     5.0   845554296
# 562          6        4     3.0   845554349
# 563          6        5     5.0   845553938
# 564          6        6     4.0   845553757
# ...        ...      ...     ...         ...
# 100831     610   166534     4.0  1493848402
# 100832     610   168248     5.0  1493850091
# 100833     610   168250     5.0  1494273047
# 100834     610   168252     5.0  1493846352
# 100835     610   170875     3.0  1493846415
#
# [21693 rows x 4 columns]

# %% [raw]
# Filter by matching multiple values in a given dataframe

# %%
df=pd.read_csv('advertising.csv')

# %%
df
# Out:
#      Daily Time Spent on Site  Age  Area Income  Daily Internet Usage  \
# 0                       68.95   35     61833.90                256.09
# 1                       80.23   31     68441.85                193.77
# 2                       69.47   26     59785.94                236.50
# 3                       74.15   29     54806.18                245.89
# 4                       68.37   35     73889.99                225.58
# ..                        ...  ...          ...                   ...
# 995                     72.97   30     71384.57                208.58
# 996                     51.30   45     67782.17                134.42
# 997                     51.63   51     42415.72                120.37
# 998                     55.55   19     41920.79                187.95
# 999                     45.01   26     29875.80                178.35
#
#                              Ad Topic Line            City  Male  \
# ...

# %%
mv=df['Country'].isin(['Tunisia','Nauru','Iceland'])

# %%
df[mv]
# Out:
#      Daily Time Spent on Site  Age  Area Income  Daily Internet Usage  \
# 0                       68.95   35     61833.90                256.09
# 1                       80.23   31     68441.85                193.77
# 4                       68.37   35     73889.99                225.58
# 41                      64.24   30     59784.18                252.36
# 68                      75.74   25     61005.87                215.25
# 163                     75.83   24     58019.64                162.44
# 349                     60.91   19     53309.61                184.94
# 418                     77.14   24     60283.98                184.88
# 910                     42.84   52     27073.27                182.20
# 947                     38.65   31     51812.71                154.77
#
#                             Ad Topic Line               City  Male  Country  \
# 0      Cloned 5thgeneration orchestration        Wrightburgh     0  Tunisia
# ...

# %% [raw]
# Filtering rows based on row number

# %%
df.filter(regex='0$',axis=0)
# Out:
#      Daily Time Spent on Site  Age  Area Income  Daily Internet Usage  \
# 0                       68.95   35     61833.90                256.09
# 10                      47.64   49     45632.51                122.02
# 20                      77.22   30     64802.33                224.44
# 30                      67.64   35     51473.28                267.01
# 40                      84.98   29     57691.95                202.61
# ..                        ...  ...          ...                   ...
# 950                     63.99   43     72802.42                138.46
# 960                     56.78   28     39939.39                124.32
# 970                     40.18   29     50760.23                151.96
# 980                     67.26   57     25682.65                168.41
# 990                     35.79   44     33813.08                165.62
#
#                                    Ad Topic Line              City  Male  \
# ...

# %% [raw]
# Find all non-zero values and check any non-zero values

# %%
df.all()
# Out:
# Daily Time Spent on Site     True
# Age                          True
# Area Income                  True
# Daily Internet Usage         True
# Ad Topic Line                True
# City                         True
# Male                        False
# Country                      True
# Timestamp                    True
# Clicked on Ad               False
# dtype: bool

# %% [raw]
# Find any non-zero values and check any non-zero values

# %%
df.any()
# Out:
# Daily Time Spent on Site    True
# Age                         True
# Area Income                 True
# Daily Internet Usage        True
# Ad Topic Line               True
# City                        True
# Male                        True
# Country                     True
# Timestamp                   True
# Clicked on Ad               True
# dtype: bool

# %%
df.notnull().all()
# Out:
# Daily Time Spent on Site    True
# Age                         True
# Area Income                 True
# Daily Internet Usage        True
# Ad Topic Line               True
# City                        True
# Male                        True
# Country                     True
# Timestamp                   True
# Clicked on Ad               True
# dtype: bool

# %%
df.isnull().any()
# Out:
# Daily Time Spent on Site    False
# Age                         False
# Area Income                 False
# Daily Internet Usage        False
# Ad Topic Line               False
# City                        False
# Male                        False
# Country                     False
# Timestamp                   False
# Clicked on Ad               False
# dtype: bool

# %%
df.iloc[:,:10:5]
# Out:
#      Daily Time Spent on Site            City
# 0                       68.95     Wrightburgh
# 1                       80.23       West Jodi
# 2                       69.47        Davidton
# 3                       74.15  West Terrifurt
# 4                       68.37    South Manuel
# ..                        ...             ...
# 995                     72.97       Duffystad
# 996                     51.30     New Darlene
# 997                     51.63   South Jessica
# 998                     55.55     West Steven
# 999                     45.01     Ronniemouth
#
# [1000 rows x 2 columns]

# %% [markdown]
# # Missing values

# %% [raw]
# Detect missing values of a given DataFrame

# %%
df.isna()
# Out:
#      Daily Time Spent on Site    Age  Area Income  Daily Internet Usage  \
# 0                       False  False        False                 False
# 1                       False  False        False                 False
# 2                       False  False        False                 False
# 3                       False  False        False                 False
# 4                       False  False        False                 False
# ..                        ...    ...          ...                   ...
# 995                     False  False        False                 False
# 996                     False  False        False                 False
# 997                     False  False        False                 False
# 998                     False  False        False                 False
# 999                     False  False        False                 False
#
#      Ad Topic Line   City   Male  Country  Timestamp  Clicked on Ad
# ...

# %% [raw]
#  Identify the columns which have at least one missing value in a DataFrame

# %%
df.isna().any()
# Out:
# Daily Time Spent on Site    False
# Age                         False
# Area Income                 False
# Daily Internet Usage        False
# Ad Topic Line               False
# City                        False
# Male                        False
# Country                     False
# Timestamp                   False
# Clicked on Ad               False
# dtype: bool

# %% [raw]
# Count the number of missing values in each column of a given DataFrame

# %%
df.isna().sum()
# Out:
# Daily Time Spent on Site    0
# Age                         0
# Area Income                 0
# Daily Internet Usage        0
# Ad Topic Line               0
# City                        0
# Male                        0
# Country                     0
# Timestamp                   0
# Clicked on Ad               0
# dtype: int64

# %% [raw]
# Find and replace the missing values in a given DataFrame which do not have any valuable information

# %%
import numpy as np

# %%
result = df.replace({"Cameroon": np.nan, "--": np.nan})

# %%
result=df.replace(['Cameroon','Davidton'],np.nan)

# %%
result
# Out:
#      Daily Time Spent on Site  Age  Area Income  Daily Internet Usage  \
# 0                       68.95   35     61833.90                256.09
# 1                       80.23   31     68441.85                193.77
# 2                       69.47   26     59785.94                236.50
# 3                       74.15   29     54806.18                245.89
# 4                       68.37   35     73889.99                225.58
# ..                        ...  ...          ...                   ...
# 995                     72.97   30     71384.57                208.58
# 996                     51.30   45     67782.17                134.42
# 997                     51.63   51     42415.72                120.37
# 998                     55.55   19     41920.79                187.95
# 999                     45.01   26     29875.80                178.35
#
#                              Ad Topic Line            City  Male  \
# ...

# %% [raw]
# Drop the rows where at least one element is missing

# %%
df.dropna()
# Out:
#      Daily Time Spent on Site  Age  Area Income  Daily Internet Usage  \
# 0                       68.95   35     61833.90                256.09
# 1                       80.23   31     68441.85                193.77
# 2                       69.47   26     59785.94                236.50
# 3                       74.15   29     54806.18                245.89
# 4                       68.37   35     73889.99                225.58
# ..                        ...  ...          ...                   ...
# 995                     72.97   30     71384.57                208.58
# 996                     51.30   45     67782.17                134.42
# 997                     51.63   51     42415.72                120.37
# 998                     55.55   19     41920.79                187.95
# 999                     45.01   26     29875.80                178.35
#
#                              Ad Topic Line            City  Male  \
# ...

# %% [raw]
# Pandas: Drop the columns where at least one element is missing

# %%
result=df.dropna(axis='columns')
result
# Out:
#      Daily Time Spent on Site  Age  Area Income  Daily Internet Usage  \
# 0                       68.95   35     61833.90                256.09
# 1                       80.23   31     68441.85                193.77
# 2                       69.47   26     59785.94                236.50
# 3                       74.15   29     54806.18                245.89
# 4                       68.37   35     73889.99                225.58
# ..                        ...  ...          ...                   ...
# 995                     72.97   30     71384.57                208.58
# 996                     51.30   45     67782.17                134.42
# 997                     51.63   51     42415.72                120.37
# 998                     55.55   19     41920.79                187.95
# 999                     45.01   26     29875.80                178.35
#
#                              Ad Topic Line            City  Male  \
# ...

# %% [raw]
# Write a Pandas program to drop the rows where all elements are missing in a given DataFrame.

# %%
result=df.dropna(how='all')
result
# Out:
#      Daily Time Spent on Site  Age  Area Income  Daily Internet Usage  \
# 0                       68.95   35     61833.90                256.09
# 1                       80.23   31     68441.85                193.77
# 2                       69.47   26     59785.94                236.50
# 3                       74.15   29     54806.18                245.89
# 4                       68.37   35     73889.99                225.58
# ..                        ...  ...          ...                   ...
# 995                     72.97   30     71384.57                208.58
# 996                     51.30   45     67782.17                134.42
# 997                     51.63   51     42415.72                120.37
# 998                     55.55   19     41920.79                187.95
# 999                     45.01   26     29875.80                178.35
#
#                              Ad Topic Line            City  Male  \
# ...

# %% [raw]
# Keep only the rows with at least 2 non-NA values

# %%
result=df.dropna(thresh=2)
result
# Out:
#      Daily Time Spent on Site  Age  Area Income  Daily Internet Usage  \
# 0                       68.95   35     61833.90                256.09
# 1                       80.23   31     68441.85                193.77
# 2                       69.47   26     59785.94                236.50
# 3                       74.15   29     54806.18                245.89
# 4                       68.37   35     73889.99                225.58
# ..                        ...  ...          ...                   ...
# 995                     72.97   30     71384.57                208.58
# 996                     51.30   45     67782.17                134.42
# 997                     51.63   51     42415.72                120.37
# 998                     55.55   19     41920.79                187.95
# 999                     45.01   26     29875.80                178.35
#
#                              Ad Topic Line            City  Male  \
# ...

# %% [raw]
# Drop those rows in which specific columns have missing values

# %%
result=df.dropna(subset=['City'])
result
# Out:
#      Daily Time Spent on Site  Age  Area Income  Daily Internet Usage  \
# 0                       68.95   35     61833.90                256.09
# 1                       80.23   31     68441.85                193.77
# 2                       69.47   26     59785.94                236.50
# 3                       74.15   29     54806.18                245.89
# 4                       68.37   35     73889.99                225.58
# ..                        ...  ...          ...                   ...
# 995                     72.97   30     71384.57                208.58
# 996                     51.30   45     67782.17                134.42
# 997                     51.63   51     42415.72                120.37
# 998                     55.55   19     41920.79                187.95
# 999                     45.01   26     29875.80                178.35
#
#                              Ad Topic Line            City  Male  \
# ...

# %% [raw]
# Total number of missing values in a DataFrame

# %%
df.isna().sum().sum()
# Out:
# 0

# %% [raw]
# Replace NaNs with a single constant value

# %%
df.fillna(0)
# Out:
#      Daily Time Spent on Site  Age  Area Income  Daily Internet Usage  \
# 0                       68.95   35     61833.90                256.09
# 1                       80.23   31     68441.85                193.77
# 2                       69.47   26     59785.94                236.50
# 3                       74.15   29     54806.18                245.89
# 4                       68.37   35     73889.99                225.58
# ..                        ...  ...          ...                   ...
# 995                     72.97   30     71384.57                208.58
# 996                     51.30   45     67782.17                134.42
# 997                     51.63   51     42415.72                120.37
# 998                     55.55   19     41920.79                187.95
# 999                     45.01   26     29875.80                178.35
#
#                              Ad Topic Line            City  Male  \
# ...

# %% [raw]
# Replace NaNs with the value from the previous row or the next row in a DataFrame

# %%
#previous row

# %%
df['Country'].fillna(method='pad',inplace=True)

# %%
#next row

# %%
df['Country'].fillna(method='bfill',inplace=True)

# %% [raw]
# Write a Pandas program to find the Indexes of missing values in a given DataFrame.

# %%
df.replace({"Davidton": np.nan, "--": np.nan},inplace=True)

# %%
df[df['City'].isnull()].index
# Out:
# Int64Index([2], dtype='int64')

# %% [raw]
# Pandas Handling Missing Values: Exercise-19 with Solution

# %%
df.fillna(df.mode().iloc[0])
# Out:
#      Daily Time Spent on Site  Age  Area Income  Daily Internet Usage  \
# 0                       68.95   35     61833.90                256.09
# 1                       80.23   31     68441.85                193.77
# 2                       69.47   26     59785.94                236.50
# 3                       74.15   29     54806.18                245.89
# 4                       68.37   35     73889.99                225.58
# ..                        ...  ...          ...                   ...
# 995                     72.97   30     71384.57                208.58
# 996                     51.30   45     67782.17                134.42
# 997                     51.63   51     42415.72                120.37
# 998                     55.55   19     41920.79                187.95
# 999                     45.01   26     29875.80                178.35
#
#                              Ad Topic Line            City  Male  \
# ...

# %% [raw]
# Heatmap of NaNs in a given DataFrame

# %%
import seaborn as sns

# %%
sns.heatmap(df.isnull(), cbar=False, cmap="YlGnBu")
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Groupby and Aggregating:

# %% [raw]
# Write a Pandas program to split the following dataframe into groups based on school code. Also check the type of GroupBy object

# %%
result=df.groupby(['City'])
result

# %%
for name,group in result:
    print(group)
# Out:
#      Daily Time Spent on Site  Age  Area Income  Daily Internet Usage  \
# 633                     40.19   37     55358.88                136.99
#
#                          Ad Topic Line       City  Male Country  \
# 633  Right-sized system-worthy project  Adamsbury     0  France
#
#                Timestamp  Clicked on Ad
# 633  2016-01-18 02:51:13              1
#      Daily Time Spent on Site  Age  Area Income  Daily Internet Usage  \
# 870                     45.82   27      64410.8                171.24
#
#                    Ad Topic Line      City  Male  Country  \
# 870  Expanded full-range synergy  Adamside     1  Eritrea
#
#                Timestamp  Clicked on Ad
# 870  2016-02-10 20:43:38              1
#      Daily Time Spent on Site  Age  Area Income  Daily Internet Usage  \
# 920                     81.05   34     54045.39                 245.5
#
#                              Ad Topic Line       City  Male   Country  \
# ...

# %% [raw]
# Write a Pandas program to split the following dataframe by school code and get mean, min, and max value of age for each school.

# %%
df_groupby=df.groupby('City').agg({'Age':['mean','min','max']})
df_groupby
# Out:
#                 Age
#                mean min max
# City
# Adamsbury      37.0  37  37
# Adamside       27.0  27  27
# Adamsstad      34.0  34  34
# Alanview       40.0  40  40
# Alexanderfurt  52.0  52  52
# ...             ...  ..  ..
# Youngburgh     23.0  23  23
# Youngfort      60.0  60  60
# Yuton          31.0  31  31
# Zacharystad    30.0  30  30
# Zacharyton     47.0  47  47
#
# [968 rows x 3 columns]

# %% [raw]
# Write a Pandas program to split the following given dataframe into groups based on 2 columns.

# %%
grps=df.groupby(['City','Country'])
for name,group in grps:
    print(name)
    print(group)
# Out:
# ('Adamsbury', 'France')
#      Daily Time Spent on Site  Age  Area Income  Daily Internet Usage  \
# 633                     40.19   37     55358.88                136.99
#
#                          Ad Topic Line       City  Male Country  \
# 633  Right-sized system-worthy project  Adamsbury     0  France
#
#                Timestamp  Clicked on Ad
# 633  2016-01-18 02:51:13              1
# ('Adamside', 'Eritrea')
#      Daily Time Spent on Site  Age  Area Income  Daily Internet Usage  \
# 870                     45.82   27      64410.8                171.24
#
#                    Ad Topic Line      City  Male  Country  \
# 870  Expanded full-range synergy  Adamside     1  Eritrea
#
#                Timestamp  Clicked on Ad
# 870  2016-02-10 20:43:38              1
# ('Adamsstad', 'Malaysia')
#      Daily Time Spent on Site  Age  Area Income  Daily Internet Usage  \
# 920                     81.05   34     54045.39                 245.5
#
# ...

# %% [raw]
# Write a Pandas program to split the following given dataframe into groups based on school code and cast grouping as a list.

# %%
list(df.groupby(['City']))
# Out:
# [('Adamsbury',
#        Daily Time Spent on Site  Age  Area Income  Daily Internet Usage  \
#   633                     40.19   37     55358.88                136.99
#
#                            Ad Topic Line       City  Male Country  \
#   633  Right-sized system-worthy project  Adamsbury     0  France
#
#                  Timestamp  Clicked on Ad
#   633  2016-01-18 02:51:13              1  ),
#  ('Adamside',
#        Daily Time Spent on Site  Age  Area Income  Daily Internet Usage  \
#   870                     45.82   27      64410.8                171.24
#
#                      Ad Topic Line      City  Male  Country  \
#   870  Expanded full-range synergy  Adamside     1  Eritrea
#
#                  Timestamp  Clicked on Ad
#   870  2016-02-10 20:43:38              1  ),
#  ('Adamsstad',
#        Daily Time Spent on Site  Age  Area Income  Daily Internet Usage  \
#   920                     81.05   34     54045.39                 245.5
#
# ...

# %% [raw]
# Write a Pandas program to split the following given dataframe into groups based on school code and cast grouping as a list.

# %%
df.groupby(['City']).size().sort_values(ascending=False)
# Out:
# City
# Lisamouth           3
# Williamsport        3
# Lake James          2
# Lake Jose           2
# Benjaminchester     2
#                    ..
# Port Anthony        1
# Port Angelamouth    1
# Port Aliciabury     1
# Phillipsbury        1
# Adamsbury           1
# Length: 968, dtype: int64

# %% [raw]
# Split the specified given dataframe into groups based on school code and call a specific group with the name of the group

# %%
group_df=df.groupby(['City'])

# %%
group_df.get_group('Lisamouth')
# Out:
#      Daily Time Spent on Site  Age  Area Income  Daily Internet Usage  \
# 235                     40.42   45     40183.75                133.90
# 777                     72.18   30     69438.04                225.02
# 829                     48.46   49     61230.03                132.38
#
#                                   Ad Topic Line       City  Male    Country  \
# 235              Stand-alone reciprocal synergy  Lisamouth     1     Norway
# 777  De-engineered attitude-oriented projection  Lisamouth     0    Bolivia
# 829             Devolved human-resource circuit  Lisamouth     1  Indonesia
#
#                Timestamp  Clicked on Ad
# 235  2016-03-16 07:59:37              1
# 777  2016-06-10 22:21:10              0
# 829  2016-01-21 23:33:22              1

# %% [raw]
# Split the specified dataframe into groups based on customer id and create a list of order date for each group

# %%
result=df.groupby('Male')['Age'].apply(list)
result
# Out:
# Male
# 0    [35, 26, 35, 33, 49, 24, 33, 37, 41, 52, 41, 5...
# 1    [31, 29, 23, 48, 30, 20, 37, 48, 23, 36, 40, 3...
# Name: Age, dtype: object

# %% [raw]
# Pandas Grouping and Aggregating: Split-Apply-Combine Exercise-11 with Solution

# %%
df = pd.DataFrame({
'ord_no':[70001,70009,70002,70004,70007,70005,70008,70010,70003,70012,70011,70013],
'purch_amt':[150.5,270.65,65.26,110.5,948.5,2400.6,5760,1983.43,2480.4,250.45, 75.29,3045.6],
'ord_date': ['05-10-2012','09-10-2012','05-10-2012','08-17-2012','10-09-2012','07-27-2012','10-09-2012','10-10-2012','10-10-2012','06-17-2012','07-08-2012','04-25-2012'],
'customer_id':[3001,3001,3005,3001,3005,3001,3005,3001,3005,3001,3005,3005],
'salesman_id': [5002,5005,5001,5003,5002,5001,5001,5006,5003,5002,5007,5001]})
print("Original Orders DataFrame:")
print(df)
# Out:
# Original Orders DataFrame:
#     ord_no  purch_amt    ord_date  customer_id  salesman_id
# 0    70001     150.50  05-10-2012         3001         5002
# 1    70009     270.65  09-10-2012         3001         5005
# 2    70002      65.26  05-10-2012         3005         5001
# 3    70004     110.50  08-17-2012         3001         5003
# 4    70007     948.50  10-09-2012         3005         5002
# 5    70005    2400.60  07-27-2012         3001         5001
# 6    70008    5760.00  10-09-2012         3005         5001
# 7    70010    1983.43  10-10-2012         3001         5006
# 8    70003    2480.40  10-10-2012         3005         5003
# 9    70012     250.45  06-17-2012         3001         5002
# 10   70011      75.29  07-08-2012         3005         5007
# 11   70013    3045.60  04-25-2012         3005         5001
